# %% [markdown]
# # Make an upward sloping line chart
#
# Made by: Cristian E. Nuno
#
# Date: June 18, 2019
#
# ## Goal
#
# Make an upward sloping line chart. Export it as a `.png` file.
#
# ## Load necessary libraries

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ## Load necessary data

# %%
x = list(range(1, 101))
y = [i**2 for i in x]

# %% [markdown]
# ## Visualize and export as `.png`

# %%
plt.scatter(x=x, y=y)
plt.title("Upward sloping chart")
plt.xlabel("x")
plt.ylabel("y (x-squared)")
plt.savefig("../images/upward_sloping_chart.png",
            dpi=300)
plt.show()
